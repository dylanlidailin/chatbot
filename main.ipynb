# %%
from dotenv import load_dotenv
import os
from langchain_openai.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS, DocArrayInMemorySearch
from langchain_core.runnables import RunnablePassthrough, RunnableParallel

# %%
load_dotenv()
API_KEY = os.getenv("OPENAI_API_KEY")
if not API_KEY:
    raise ValueError("Please set the OPENAI_API_KEY environment variable.")

# %%
from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI(
  openai_api_key=API_KEY,
  model_name="gpt-4",
)
response_text = llm.invoke("What is coding?")
print(response_text)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[19], line 7
#       1 from langchain.chat_models import ChatOpenAI
#       3 llm = ChatOpenAI(
#       4   openai_api_key=API_KEY,
#       5   model_name="gpt-4",
#       6 )
# ----> 7 response_text = llm.invoke("What is coding?")
#       8 print(response_text)
#
# File ~/chatbot/tech/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:370, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     358 @override
#     359 def invoke(
#     360     self,
#    (...)    365     **kwargs: Any,
#     366 ) -> BaseMessage:
#     367     config = ensure_config(config)
#     368     return cast(
#     369         "ChatGeneration",
# --> 370         self.generate_prompt(
#     371             [self._convert_input(input)],
#     372             stop=stop,
#     373             callbacks=config.get("callbacks"),
#     374             tags=config.get("tags"),
#     375             metadata=config.get("metadata"),
#     376             run_name=config.get("run_name"),
#     377             run_id=config.pop("run_id", None),
#     378             **kwargs,
#     379         ).generations[0][0],
#     380     ).message
#
# File ~/chatbot/tech/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:947, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     938 @override
#     939 def generate_prompt(
#     940     self,
#    (...)    944     **kwargs: Any,
#     945 ) -> LLMResult:
#     946     prompt_messages = [p.to_messages() for p in prompts]
# --> 947     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/chatbot/tech/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:766, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     763 for i, m in enumerate(input_messages):
#     764     try:
#     765         results.append(
# --> 766             self._generate_with_cache(
#     767                 m,
#     768                 stop=stop,
#     769                 run_manager=run_managers[i] if run_managers else None,
#     770                 **kwargs,
#     771             )
#     772         )
#     773     except BaseException as e:
#     774         if run_managers:
#
# File ~/chatbot/tech/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1012, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1010     result = generate_from_stream(iter(chunks))
#    1011 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1012     result = self._generate(
#    1013         messages, stop=stop, run_manager=run_manager, **kwargs
#    1014     )
#    1015 else:
#    1016     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/chatbot/tech/lib/python3.13/site-packages/langchain_community/chat_models/openai.py:476, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     470 message_dicts, params = self._create_message_dicts(messages, stop)
#     471 params = {
#     472     **params,
#     473     **({"stream": stream} if stream is not None else {}),
#     474     **kwargs,
#     475 }
# --> 476 response = self.completion_with_retry(
#     477     messages=message_dicts, run_manager=run_manager, **params
#     478 )
#     479 return self._create_chat_result(response)
#
# File ~/chatbot/tech/lib/python3.13/site-packages/langchain_community/chat_models/openai.py:387, in ChatOpenAI.completion_with_retry(self, run_manager, **kwargs)
#     385 """Use tenacity to retry the completion call."""
#     386 if is_openai_v1():
# --> 387     return self.client.create(**kwargs)
#     389 retry_decorator = _create_retry_decorator(self, run_manager=run_manager)
#     391 @retry_decorator
#     392 def _completion_with_retry(**kwargs: Any) -> Any:
#
# File ~/chatbot/tech/lib/python3.13/site-packages/openai/_utils/_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File ~/chatbot/tech/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:925, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     882 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     883 def create(
#     884     self,
#    (...)    922     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     923 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     924     validate_response_format(response_format)
# --> 925     return self._post(
#     926         "/chat/completions",
#     927         body=maybe_transform(
#     928             {
#     929                 "messages": messages,
#     930                 "model": model,
#     931                 "audio": audio,
#     932                 "frequency_penalty": frequency_penalty,
#     933                 "function_call": function_call,
#     934                 "functions": functions,
#     935                 "logit_bias": logit_bias,
#     936                 "logprobs": logprobs,
#     937                 "max_completion_tokens": max_completion_tokens,
#     938                 "max_tokens": max_tokens,
#     939                 "metadata": metadata,
#     940                 "modalities": modalities,
#     941                 "n": n,
#     942                 "parallel_tool_calls": parallel_tool_calls,
#     943                 "prediction": prediction,
#     944                 "presence_penalty": presence_penalty,
#     945                 "reasoning_effort": reasoning_effort,
#     946                 "response_format": response_format,
#     947                 "seed": seed,
#     948                 "service_tier": service_tier,
#     949                 "stop": stop,
#     950                 "store": store,
#     951                 "stream": stream,
#     952                 "stream_options": stream_options,
#     953                 "temperature": temperature,
#     954                 "tool_choice": tool_choice,
#     955                 "tools": tools,
#     956                 "top_logprobs": top_logprobs,
#     957                 "top_p": top_p,
#     958                 "user": user,
#     959                 "web_search_options": web_search_options,
#     960             },
#     961             completion_create_params.CompletionCreateParamsStreaming
#     962             if stream
#     963             else completion_create_params.CompletionCreateParamsNonStreaming,
#     964         ),
#     965         options=make_request_options(
#     966             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     967         ),
#     968         cast_to=ChatCompletion,
#     969         stream=stream or False,
#     970         stream_cls=Stream[ChatCompletionChunk],
#     971     )
#
# File ~/chatbot/tech/lib/python3.13/site-packages/openai/_base_client.py:1239, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1225 def post(
#    1226     self,
#    1227     path: str,
#    (...)   1234     stream_cls: type[_StreamT] | None = None,
#    1235 ) -> ResponseT | _StreamT:
#    1236     opts = FinalRequestOptions.construct(
#    1237         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1238     )
# -> 1239     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/chatbot/tech/lib/python3.13/site-packages/openai/_base_client.py:1034, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1031             err.response.read()
#    1033         log.debug("Re-raising status error")
# -> 1034         raise self._make_status_error_from_response(err.response) from None
#    1036     break
#    1038 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************_TgA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
parser = StrOutputParser()
chain = llm | parser
chain.invoke("What is coding?")
# Out:
# 'Coding, also known as programming, is the process of creating instructions for computers to follow. It involves writing scripts, functions, and algorithms that guide the computer to perform certain tasks. This can include creating software, apps, websites, video games, and more. Coding languages include Python, Java, C++, JavaScript, and many others.'

# %%
file_loader = PyPDFLoader("Knn and Prob-1.pdf")
page = file_loader.load_and_split()
page
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 0, 'page_label': '1'}, page_content='KNN and Probability'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 1, 'page_label': '2'}, page_content='Classification\n\uf0d8Definition\n\uf076Classification can take two distinct meanings in Machine Learning\n\uf0d8Unsupervised Learning \n\uf076We may be given a set of observations with the aim of establishing \nthe existence of classes or clusters in the data\n\uf0d8Supervised Learning \n\uf076We may know for certain that there are so many classes, and the aim \nis to establish a rule that we can use to classify a new observation into \none of the existing classes\n\uf076k-NN is a supervised method for classification \n2'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 2, 'page_label': '3'}, page_content='Classification\n\uf0d8A few classification examples:\n\uf076A Person arrives at the emergency room with a set of symptoms that could \npossibly be attributed to one of three medical conditions. Which of the three \nconditions does the individual have?\n\uf076An online banking service must be able to determine whether or not a \ntransaction being performed on the site is fraudulent, on the basis of the \nuser’s IP address, past transaction history, and so forth.\n\uf076On the basis of DN sequence data for a number of patients with and without \na given disease, a biologist would like to figure out which DNA mutations are \ndisease-causing and which are not.\n3'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 3, 'page_label': '4'}, page_content='Classification\n\uf0d8There are many possible techniques that a classifier might use to \npredict a qualitative response. Today we will discuss k-NN\n\uf076k-Nearest Neighbors\n\uf076Naïve Bayes \n\uf076Logistic Regression\n\uf076Tree – based methods\n4'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 4, 'page_label': '5'}, page_content='Classification\nA few issues to keep in mind when building a classifier\n\uf0d8Accuracy. There is the reliability of the rule, usually represented by the \nproportion of correct classifications, although it may be that some errors are \nmore serious than others, and it may be important to control the error rate for \nsome key class.\n\uf0d8Speed. In some circumstances, the speed of the classifier is a major issue. A \nclassifier that is 85% accurate may be preferred over one that is 95% accurate if it \nis 100 times faster in testing (and such differences in time-scales are not \nuncommon in neural networks for example). \n\uf076Such considerations would be important for the automatic reading of postal \ncodes, or automatic fault detection of items on a production line for example.\n5'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 5, 'page_label': '6'}, page_content='Classification\nA few issues to keep in mind when building a classifier\n\uf0d8Comprehensibility. If it is a human operator that must apply the classification \nprocedure, the procedure must be easily understood else mistakes will be made \nin applying the rule. It is important also, that human operators believe the \nsystem. \n\uf0d8Training Time. Especially in a rapidly changing environment, it may be necessary \nto learn a classification rule quickly, or make adjustments to an existing rule in \nreal time. “Quickly” might imply also that we need only a small number of \nobservations to establish our rule.\n6'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 6, 'page_label': '7'}, page_content='K-Nearest Neighbors\n7'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 7, 'page_label': '8'}, page_content='Simple approach for k-NN\nSimple goal:\n\uf0d8Predict the label of a data point by:\n\uf076Looking at the ‘k’ closest labeled data points (neighbors)\n\uf076Uses a majority vote\n\uf0d8One of the easiest algorithms to interpret, oftentimes used as a baseline for \nmeasuring model performance\n\uf0d8Memory-Based Learning\n\uf076Also known as “case-based” or “example-based” learning\n\uf0d8Intuition behind memory-based learning\n\uf076Similar inputs map to similar outputs\n\uf0d8If true, we just have to define “similar”\n\uf0d8 Not all similarities created equal…\n8'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 8, 'page_label': '9'}, page_content='Memory-Based Learning\n\uf0d8How do we determine “similar”?\n\uf0d8For instance, if we wanted to:\n\uf0d8Predict Brian’s weight\n\uf076Who are the similar people?\n\uf076Similar age, diet, height, waistline, activity level …\n\uf0d8Predict Brian’s IQ\n\uf076Similar occupation, writing style, undergraduate degree, SAT \nscore, …\n\uf0d8How do we calculate variously ranges in similarity?\n\uf076Need some metric…\n\uf0d8Distance\n9'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 9, 'page_label': '10'}, page_content='k-NN Approach\n\uf0d8Define a distance 𝑑𝑑(𝑥𝑥1, 𝑥𝑥2) between any 2 examples\n\uf076Examples are essentially rows\n\uf076So we could just use Euclidean distance … \n\uf0d8Training\n\uf076Index the training examples for fast lookup (build a “database”)\n\uf0d8Test\n\uf076Given a new 𝑥𝑥, find the closest neighbor (k=1) from training index\n\uf076Classify x the same as its closest neighbor\n10'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 10, 'page_label': '11'}, page_content='k-NN Approach\n\uf0d8Euclidean Distance Equation:\n\uf0d8p & z are the current data and q is new, think of p & z as the training and q as the \ntest. \n11\nx1 x2 x3 x4 x5 x6 x7 x8 Result\nq 3 2 2 5 6 2 1 5\np 4 3 3 6 4 4 5 6\nEuclidean 1 1 1 1 4 4 16 1 5.39\nz 3 2 2 5 6 2 1 5\nEuclidean 0 0 0 0 0 0 0 0 0\nSubtracting then \nsquaring row p \nwith q. Then \nsumming and \ntaking the sqrt. \nDo the same with \nz and compare'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 11, 'page_label': '12'}, page_content='kNN Decision Boundaries\n\uf0d8kNN can learn complex decision boundaries\n12'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 12, 'page_label': '13'}, page_content='\uf0d8Instead of picking the (1) nearest neighbor, what if we picked the \nk-Nearest Neighbors and have them vote?\n\uf0d8Choosing k points is more reliable in the following cases:\n\uf076Noise in training vectors x\n\uf076Noise in training labels y\n\uf076Overlapping classes\nkNN\n13\nx_1\nx_2\n++\n+\n+\n+\n++++\no\no\no\no\no\nooo oo\no\n+\n+\n+o\no o\nk=1'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 13, 'page_label': '14'}, page_content='kNN\n\uf0d8Instead of picking the (1) nearest neighbor, what if we picked the \nk-Nearest Neighbors and have them vote?\n\uf0d8Choosing k points is more reliable in the following cases:\n\uf076Noise in training vectors x\n\uf076Noise in training labels y\n\uf076Overlapping classes\n\uf0d8Why?\n14\nx_1\nx_2 ++\n+\n+\n+\n++++\no\no\no\no\no\nooo oo\no\n+\n+\n+o\no o\nk=1X'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 14, 'page_label': '15'}, page_content='kNN Decision Boundaries\n\uf0d8Consider this example with R,G,B classes \nwith significant overlap\n15'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 15, 'page_label': '16'}, page_content='kNN Decision Boundaries\n\uf0d8Consider this example with R,G,B classes \nwith significant overlap\n\uf0d8k=1 Decision Boundary\n\uf076Looks complex\n\uf076Overfitting?\n16'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 16, 'page_label': '17'}, page_content='kNN Decision Boundaries\n\uf0d8k=1 Decision Boundary\n\uf076Looks complex\n\uf076Overfitting?\n\uf0d8What if we were to increase k?\n17'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 17, 'page_label': '18'}, page_content='kNN Decision Boundaries\n\uf0d8k=1 Decision Boundary\n\uf076Looks complex\n\uf076Overfitting?\n\uf0d8What if we were to increase k?\n\uf076K=15 Decision boundary\n18'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 18, 'page_label': '19'}, page_content='kNN Decision Boundaries\n\uf0d8k=1 Decision Boundary\n\uf076Looks complex\n\uf076Overfitting?\n\uf0d8What if we were to increase k?\n\uf076K=15 Decision boundary\n\uf076Smoother boundaries\n19'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 19, 'page_label': '20'}, page_content='kNN Decision Boundaries\n\uf0d8k=1 Decision Boundary\n\uf076Looks complex\n\uf076Overfitting?\n\uf0d8What if we were to increase k?\n\uf076K=15 Decision boundary\n\uf076Smoother boundaries\n\uf076Generalizes better on unseen data\n20'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 20, 'page_label': '21'}, page_content='kNN Decision Boundaries\n\uf0d8k=1 Decision Boundary\n\uf076Looks complex\n\uf076Overfitting?\n\uf0d8What if we were to increase k?\n\uf076K=15 Decision boundary\n\uf076Smoother boundaries\n\uf076Generalizes better on unseen data\n\uf0d8What makes the boundaries smoother?\n21'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 21, 'page_label': '22'}, page_content='kNN Decision Boundaries\n\uf0d8k=1 Decision Boundary\n\uf076Looks complex\n\uf076Overfitting?\n\uf0d8What if we were to increase k?\n\uf076K=15 Decision boundary\n\uf076Smoother boundaries\n\uf076Generalizes better on unseen data\n\uf0d8What makes the boundaries smoother?\n\uf0d8Let’s look at a two-class (binary) example\n22'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 22, 'page_label': '23'}, page_content='k-NN Graphical Example\n23\n\uf0d8Consider this two-dimensional dataset with \npoints classified as Red or Green'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 23, 'page_label': '24'}, page_content='k-NN Graphical Example\n24\n\uf0d8Consider this two-dimensional dataset with \npoints classified as Red or Green \n\uf0d8We want to Classify this point'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 24, 'page_label': '25'}, page_content='k-NN Graphical Example\n25\n\uf0d8Consider this two-dimensional dataset with \npoints classified as Red or Green \n\uf0d8We want to Classify this point\n\uf0d8If we consider k=3 neighbors'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 25, 'page_label': '26'}, page_content='k-NN Graphical Example\n26\n\uf0d8Consider this two-dimensional dataset with \npoints classified as Red or Green \n\uf0d8We want to Classify this point\n\uf0d8If we consider k=3 neighbors \n\uf076Measured by some distance\nd'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 26, 'page_label': '27'}, page_content='k-NN Graphical Example\n27\n\uf0d8Consider this two-dimensional dataset with \npoints classified as Red or Green \n\uf0d8We want to Classify this point\n\uf0d8If we consider k=3 neighbors \n\uf076Measured by some distance\n\uf076The point is classified as Red'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 27, 'page_label': '28'}, page_content='k-NN Graphical Example\n28\n\uf0d8Consider this two-dimensional dataset with \npoints classified as Red or Green \n\uf0d8We want to Classify this point\n\uf0d8If we consider k=3 neighbors \n\uf076Measured by some distance\n\uf076The point is classified as Red\n\uf0d8If we consider k=5 neighbors'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 28, 'page_label': '29'}, page_content='k-NN Graphical Example\n29\n\uf0d8Consider this two-dimensional dataset with \npoints classified as Red or Green \n\uf0d8We want to Classify this point\n\uf0d8If we consider k=3 neighbors \n\uf076Measured by some distance\n\uf076The point is classified as Red\n\uf0d8If we consider k=5 neighbors\n\uf076Measured by some distance\nd'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 29, 'page_label': '30'}, page_content='k-NN Graphical Example\n30\n\uf0d8Consider this two-dimensional dataset with \npoints classified as Red or Green \n\uf0d8We want to Classify this point\n\uf0d8If we consider k=3 neighbors \n\uf076Measured by some distance\n\uf076The point is classified as Red\n\uf0d8If we consider k=5 neighbors\n\uf076Measured by some distance\n\uf076The point is classified as Green'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 30, 'page_label': '31'}, page_content='k-NN Graphical Example\n31\n\uf0d8Consider this two-dimensional dataset with \npoints classified as Red or Green \n\uf0d8We want to Classify this point\n\uf0d8If we consider k=3 neighbors \n\uf076Measured by some distance\n\uf076The point is classified as Red\n\uf0d8If we consider k=5 neighbors\n\uf076Measured by some distance\n\uf076The point is classified as Green\n\uf0d8So, how do we know what k to choose?'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 31, 'page_label': '32'}, page_content='How to choose “k”\n\uf0d8Odd k (often 1, 3, or 5):\n\uf076Avoids problem of breaking ties (in a binary classifier)\n\uf0d8Large k:\n\uf076Less sensitive to noise (particularly class noise)\n\uf076Better probability estimates for discrete classes\n\uf076Larger training sets allow larger values of k\n\uf0d8Small k:\n\uf076Captures fine structure of problem space better\n\uf076May be necessary with small training sets\n\uf0d8Balance between large and small k\n32'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 32, 'page_label': '33'}, page_content='kNN distance problem\n\uf0d8Problem:\n\uf076What if the input represents weight in milligrams?\n\uf076Then small differences in physical weight dimension have a \nhuge effect on distances, overwhelming other features\n\uf076Should really correct for these arbitrary “scaling” issues\n\uf0d8This leads to Standard Scaling\n\uf0d8Rescale weights so that standard deviation = 1\n33\n+\no o\n+\nweight (lb)\nattribute_2++\n+\n++ +\n+\no\no\noo ooo\noo\nweight (mg)\nattribute_2\n+\n+ +\n+\n++ +\n+\n+\no\no\noo\no\nooo\noo\nobad'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 33, 'page_label': '34'}, page_content='More kNN Details\n\uf0d8Nonparametric - makes no explicit assumptions about the underlying distribution \nof the input\n\uf0d8Instance/memory-based learning means that this algorithm doesn’t explicitly \nlearn a model. Instead, it chooses to memorize the training instances which are \nsubsequently used as “knowledge” for the prediction phase\n\uf0d8Learns arbitrarily complicated decision boundaries\n\uf0d8Lazy learner - method that generalizes data in the testing (deployment) phase, \nrather than during the training phase – designed to be continuously updating as \nnew data comes in\n\uf076A benefit of lazy learning is that it can quickly adapt to changes, \n\uf0d8Think Netflix recommendations, new options are appearing constantly so have a static training set \nit’s really valuable.  \n\uf076Very fast training time, but very slow prediction (has to search for the nearest \nneighbors)\n34'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 34, 'page_label': '35'}, page_content='Advantages of k-NN\n\uf0d8Simple and fast to deploy\n\uf076Little to no training time\n\uf0d8Easy to interpret/explain\n\uf0d8Naturally handles multiclass datasets\n\uf0d8Non-parametric \n\uf076Does not assume any probability distributions on the input data\n35'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 35, 'page_label': '36'}, page_content='Disadvantages of k-NN\n\uf0d8Storage of model takes a lot of disk space (contains entire training \ndataset)\n\uf0d8Curse of Dimensionality - often works best with 25 or fewer \ndimensions\n\uf076There is little difference between the nearest and farthest \nneighbor in high dimensional data (starts to normalize to 1)\n\uf0d8Computationally expensive predictions (large search problem to find \nnearest neighbors)\n\uf076Might be impractical in industry settings\n\uf0d8Need to normalize - suffers from skewed class distributions\n\uf076If one type of category occurs much more than another, \nclassifying an input will be more biased towards that one category \n(dominates the majority vote since it is more likely to be neighbors \nwith the input) 36'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 36, 'page_label': '37'}, page_content='kNN Exercise\n37\nSwitch to R'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 37, 'page_label': '38'}, page_content='Understanding Probability Classifiers\n\uf0d8To be able to unpack the probability classifiers, we need a good grasp on the \nfollowing topics\n\uf076Random variables\n\uf076Distributions\n\uf0d8Continuous \n\uf0d8Discrete\n\uf076Statistical Independence\n\uf076Probability\n\uf0d8Conditional Probability\n\uf0d8Joint Probability\n\uf0d8Marginal Probability\n38'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 38, 'page_label': '39'}, page_content="Random Variables\n\uf0d8A random variable is a random number determined by chance, or more formally, \ndrawn according to a probability distribution which specifies the probability that \nits value falls in any given interval.\n\uf0d8Discrete Random Variable\n\uf076Taking any of a specified finite or countable list of values, endowed with \na probability mass function characteristic of the random variable's probability \ndistribution\n\uf0d8Continuous\n\uf076Taking any numerical value in an interval or collection of intervals, via \na probability density function that is characteristic of the random variable's \nprobability distribution\n39"),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 39, 'page_label': '40'}, page_content='Random Variables\n\uf0d8Why do we care about Random Variables?\n\uf0d8Our goal is to predict the target/class\n\uf0d8We are not given the true (presumably deterministic) function\n\uf0d8We are only given observations\n\uf0d8Uncertainty arises through:\n\uf076Noisy measurements\n\uf076Finite size of data sets\n\uf076Ambiguity: The word “bank” can mean (1) a financial institution, (2) the side of a \nriver,or (3) tilting an airplane. Which meaning was intended, based on the words that \nappear nearby?\n\uf0d8Probability theory provides a consistent framework for the quantification \nand manipulation of uncertainty\n\uf0d8Allows us to make optimal predictions given all the information available to \nus, even though that information may be incomplete or ambiguous\n40'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 40, 'page_label': '41'}, page_content='Probability\n\uf0d8Probabilities assign numbers to possibilities\n\uf0d8A probability needs to satisfy three properties (Kolmogorov, 1956):\n\uf076A probability must be nonnegative\n\uf076The sum of the probabilities across all events in the entire sample space \nmust be 1\n\uf076For any two mutually exclusive events, the probability that one or the other \noccurs is the sum of their individual probabilities\n\uf0d8For example, the probability that a fair six-sided die comes up 3 OR 4 is 1/6 + 1/6 = 2/6.\n41'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 41, 'page_label': '42'}, page_content='Probability Distributions\n\uf0d8A probability distribution is simply a list of all possible events and their \ncorresponding probabilities\n\uf0d8There are two kinds of probability distributions\n\uf076Discrete Distribution:\n\uf0d8Probability of heads or tails\n\uf076Continuous Distribution:\n\uf0d8Probabilities of people’s heights\n42'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 42, 'page_label': '43'}, page_content='Discrete Probability Distribution\n\uf0d8When the sample space consists of discrete outcomes (e.g., heads or tails), the \nprobability distribution is a list of probabilities of the outcomes\n\uf0d8The probability of a discrete outcome is called a probability mass\n\uf0d8The sum of the probability masses across the sample space must be 1\n43'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 43, 'page_label': '44'}, page_content='Discrete Probability Example\n\uf0d8Example\n\uf076Consider the simple experiment of tossing a coin three times. Let X = number \nof times the coin comes up heads. The 8 possible elementary events and the \ncorresponding values for X are:\n44\nElementary Event Count of Heads (X)\nTTT 0\nTTH 1\nTHT 1\nHTT 1\nTHH 2\nHTH 2\nHHT 2\nHHH 3'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 44, 'page_label': '45'}, page_content='Discrete Probability Example\n\uf0d8Example\n\uf076Therefore, the probability distribution for the number of heads occurring in \nthree coin tosses is\n45\nCount of Heads (X) p(x) F(x)\n0 1/8 1/8\n1 3/8 4/8\n2 3/8 7/8\n3 1/8 1'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 45, 'page_label': '46'}, page_content='Discrete Probability Example\n46\nCount of Heads (X) p(x) F(x)\n0 1/8 1/8\n1 3/8 4/8\n2 3/8 7/8\n3 1/8 1'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 46, 'page_label': '47'}, page_content='Continuous Probability Distribution\n\uf0d8When the sample space consists of continuous outcomes (ex: \npeople’s heights) we cannot use probability mass for a specific \noutcome.\n\uf0d8Why not?\n47'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 47, 'page_label': '48'}, page_content='Continuous Probability Distribution – Probability Density\n\uf0d8When the sample space consists of continuous outcomes (ex: people’s heights) \nwe cannot use probability mass for a specific outcome.\n\uf0d8Why not?\n\uf076Because the probability mass for a specific outcome will be zero\n\uf076In other words, the probability of someone’s height being exactly \n67.2141390842076153…\n\uf0d8Instead, we can:\n\uf076Discretize the space into a finite set of mutually exclusive and exhaustive \nintervals\n\uf076Calculate the probability mass in each interval\n\uf076Use the ratio of probability mass to interval width\n\uf076This ratio is called the Probability Density\n48'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 48, 'page_label': '49'}, page_content='Probability Density\n\uf0d8The top panel of this figure shows the \ndiscretized intervals and probability mass in \neach interval\n\uf0d8The second panel shows the probability density\n\uf0d8The third panel shows the narrower intervals \nand probability mass in each interval\n\uf0d8The bottom panel shows the probability density \ncorresponding to the more narrow intervals\n\uf0d8Generally, the skinnier the intervals are, the \nmore accurate the probability density is\n49'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 49, 'page_label': '50'}, page_content='Probability Density\n\uf0d8While probability mass cannot \nexceed 1, probability densities \ncan\n\uf0d8The upper panel of this figure \nshows that most of the \nprobability mass is concentrated \naround 84\n\uf0d8Consequently, the probability \ndensity near 84 exceeds 1.0, as \nshown in the lower panel\n\uf0d8This simply means that there is a \nhigh concentration of probability \nmass relative to the width of the \ninterval\n50'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 50, 'page_label': '51'}, page_content='Properties of Probability Density Functions\n\uf0d8We need to define some notations first\n\uf0d8Let:\n\uf076𝑥𝑥 be the continuous variable\n\uf076Δ𝑥𝑥 be the width of an interval on 𝑥𝑥\n\uf076𝑖𝑖 be an index for the intervals\n\uf076[𝑥𝑥𝑖𝑖, 𝑥𝑥𝑖𝑖 + ∆𝑥𝑥] be the interval between 𝑥𝑥𝑖𝑖 and 𝑥𝑥𝑖𝑖 + ∆𝑥𝑥\n\uf076𝑃𝑃([𝑥𝑥𝑖𝑖, 𝑥𝑥𝑖𝑖 + ∆𝑥𝑥])be the probability mass of the 𝑖𝑖th interval\n\uf0d8Then the sum of those probability masses must be 1:\n�\n𝑖𝑖\n𝑃𝑃 𝑥𝑥𝑖𝑖, 𝑥𝑥𝑖𝑖 + ∆𝑥𝑥 = 1\n\uf0d8We can rewrite the equation above in terms of the density of each interval, by  \ndividing and multiplying by x:\n�\n𝑖𝑖\n∆𝑥𝑥 ∗𝑃𝑃 𝑥𝑥𝑖𝑖, 𝑥𝑥𝑖𝑖 + ∆𝑥𝑥\n∆𝑥𝑥 = 1\n51'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 51, 'page_label': '52'}, page_content='Properties of Probability Density Functions\n\uf0d8In the limit, as the interval width becomes infinitesimal, we denote:\n\uf076Summation as ∫ instead of ∑\n\uf0d8Then, the previous equation (in terms of density) can be rewritten as:\n�\n𝑖𝑖\n∆𝑥𝑥∗𝑃𝑃 𝑥𝑥𝑖𝑖, 𝑥𝑥𝑖𝑖 + ∆𝑥𝑥\n∆𝑥𝑥 = 1 ⇒ �𝑑𝑑𝑥𝑥𝑝𝑝 𝑥𝑥 = 1\n\uf0d8We use 𝑝𝑝(𝑥𝑥) to represent the probability mass when 𝑥𝑥is discrete\n\uf0d8Thus, what 𝑝𝑝(𝑥𝑥) represents depends on the context\n52'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 52, 'page_label': '53'}, page_content='The Normal Probability Density Functions\n\uf0d8Perhaps the most famous probability density \nfunction is the normal distribution, also known \nas the Gaussian distribution\n\uf0d8The probability density function of normal \ndistribution is\np 𝑥𝑥 = 1\n𝜎𝜎√2𝜋𝜋𝑒𝑒\n−1\n2\n𝑥𝑥−𝜇𝜇\n𝜎𝜎\n2\n\uf0d8Recall, what are 𝜎𝜎and 𝜇𝜇? what do they control?\n\uf0d8An example of the probability density is shown in \nthe figure where the x axis is divided into a \ndense comb of small intervals\n\uf0d8The figure also shows that the area under the \ncurve is, in fact, 1\n53'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 53, 'page_label': '54'}, page_content='Example - Continuous Normal Distribution\n\uf0d8Example of the continuous distribution of weights\n\uf076The continuous normal distribution can describe \nthe distribution of weight of adult males. \n\uf076For example, you can calculate the probability \nthat a man weighs between 160 and 170 pounds.\n\uf076The area of this range is 0.136; therefore, the \nprobability that a randomly selected man weighs \nbetween 160 and 170 pounds is 13.6%. \n\uf076The entire area under the curve equals 1.0\n�\n−∞\n+∞\n𝑝𝑝 𝑥𝑥 𝑑𝑑𝑥𝑥 = 1\n54'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 54, 'page_label': '55'}, page_content='Joint Probability\n\uf0d8Joint Probability\n\uf076Knowing that y occurred reduces the sample space to y\n\uf0d8The part of y where x also occurred, or the probability of x and y occurring, is:\n\uf0d8𝑃𝑃 𝑥𝑥, 𝑦𝑦 = 𝑃𝑃(𝑥𝑥∩𝑦𝑦)\n\uf076Order does not matter:\n\uf0d8𝑃𝑃(𝑥𝑥, 𝑦𝑦) = 𝑃𝑃(𝑦𝑦, 𝑥𝑥)\n55\n\uf0d8Disjoint Sets \n\uf0d8Mutually Exclusive Events\n\uf0d8𝑥𝑥 ∩𝑦𝑦 = ∅\n\uf0d8Intersecting sets'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 55, 'page_label': '56'}, page_content='Joint Probability and Marginal Probability\n56\n\uf0d8This table shows the probabilities of various combinations \nof people’s eye/hair color\n\uf0d8Each entry indicates the joint probability of particular \ncombinations of eye color (𝑒𝑒) and hair color (ℎ), denoted \nby 𝑝𝑝(𝑒𝑒, ℎ)\n\uf0d8The right margin of the table shows the probabilities of \nthe eye colors overall, collapsed across hair colors\n\uf0d8Such probabilities are called marginal probability, \ndenoted by 𝑝𝑝(𝑒𝑒):\n𝑝𝑝 𝑒𝑒 = �\nℎ\n𝑝𝑝(𝑒𝑒, ℎ)\n\uf0d8The marginal probabilities of the hair colors, 𝑝𝑝(ℎ), are \nindicated on the lower margin of the table:\n𝑝𝑝 ℎ = �\n𝑒𝑒\n𝑝𝑝(𝑒𝑒, ℎ)'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 56, 'page_label': '57'}, page_content='Conditional Probability\n\uf0d8Conditional Probability\n\uf076P 𝑥𝑥 𝑦𝑦 is the probability of the occurrence of event 𝑥𝑥, given that 𝑦𝑦occurred is given as:\n\uf0d8P 𝑥𝑥 𝑦𝑦 =\n𝑃𝑃(𝑥𝑥∩𝑦𝑦)\n𝑃𝑃(𝑦𝑦) =\n𝑃𝑃(𝑥𝑥,𝑦𝑦)\n𝑃𝑃(𝑦𝑦)\n\uf076Answers the question: \n\uf0d8How does the probability of an event change if we have extra information?\n57'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 57, 'page_label': '58'}, page_content='Conditional Probability Example\n\uf0d8Coin Toss Example:\n\uf076Toss a fair coin 3 times\n\uf076What is the probability of 3 heads?\n\uf0d8Answer: \n\uf076𝑆𝑆𝑆𝑆𝑆𝑆𝑝𝑝𝑆𝑆𝑒𝑒𝑆𝑆𝑝𝑝𝑆𝑆𝑆𝑆𝑒𝑒 = {𝐻𝐻𝐻𝐻𝐻𝐻, 𝐻𝐻𝐻𝐻𝐻𝐻, 𝐻𝐻𝐻𝐻𝐻𝐻, 𝐻𝐻𝐻𝐻𝐻𝐻, 𝐻𝐻𝐻𝐻𝐻𝐻, 𝐻𝐻𝐻𝐻𝐻𝐻, 𝐻𝐻𝐻𝐻𝐻𝐻, 𝐻𝐻𝐻𝐻𝐻𝐻}\n\uf076All outcomes are equally likely (if the coin is fair)\n\uf076𝑃𝑃(𝐻𝐻𝐻𝐻𝐻𝐻) =\n1\n8\n\uf076Suppose we are told that the first toss was heads\n\uf076Given this information, how should we compute the probability of {HHH}?\n\uf0d8Answer: \n\uf076We have a new (reduced) 𝑆𝑆𝑆𝑆𝑆𝑆𝑝𝑝𝑆𝑆𝑒𝑒𝑆𝑆𝑝𝑝𝑆𝑆𝑆𝑆𝑒𝑒 = {𝐻𝐻𝐻𝐻𝐻𝐻, 𝐻𝐻𝐻𝐻𝐻𝐻, 𝐻𝐻𝐻𝐻𝐻𝐻, 𝐻𝐻𝐻𝐻𝐻𝐻}\n\uf076All outcomes are still equally likely (the coin is still fair)\n\uf076𝑃𝑃(𝐻𝐻𝐻𝐻𝐻𝐻) =\n1\n4\n58'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 58, 'page_label': '59'}, page_content='Conditional Probability Example\n\uf0d8We can visualize the conditional probability \nas follows\n\uf076Think of 𝑃𝑃(𝐴𝐴) as the proportion of the \narea of the whole sample space taken \nup by A\n\uf076For 𝑃𝑃(𝐴𝐴|𝐵𝐵) we restrict our attention to \nB\n\uf076𝑃𝑃(𝐴𝐴|𝐵𝐵) is the proportion of B taken up \nby A\n\uf0d8𝑃𝑃 𝐴𝐴 𝐵𝐵 =\n𝑃𝑃(𝐴𝐴∩𝐵𝐵)\n𝑃𝑃(𝐵𝐵)\n59'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 59, 'page_label': '60'}, page_content='Statistical Independence\n\uf0d8Independent Events\n\uf076If x and y are independent then they are unconnected and not related to each \nother\n\uf076We have:\nP 𝑥𝑥 𝑦𝑦 = 𝑃𝑃 𝑥𝑥\n\uf076From there it follows that\n𝑃𝑃 𝑥𝑥, 𝑦𝑦 = 𝑃𝑃 𝑥𝑥 ∗𝑃𝑃(𝑦𝑦)\n\uf076In other words, knowing that y occurred does not change the probability that x \noccurs (and vice versa)\n\uf076Examples of absolute independence include:\n\uf0d8Eye color and height\n\uf0d8Hair color and weight\n60'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 60, 'page_label': '61'}, page_content='Statistical Independence Example\n\uf0d8Independent Events\n\uf076If we want to calculate the joint probability of two independent events, \nwe can simply multiply each probability together to get the joint \nprobability\n\uf076“Joint Distribution” = “Product Distribution”\n\uf076P 𝑥𝑥, 𝑦𝑦 = 𝑃𝑃 𝑥𝑥 ∗𝑃𝑃(𝑦𝑦)\n\uf0d8For Example:\n\uf076Probability of tossing a coin and getting “Heads”:\n𝑃𝑃 𝐻𝐻𝑒𝑒𝑆𝑆𝑑𝑑𝐻𝐻 = 𝑃𝑃 𝑥𝑥 = 1\n2\n\uf076Probability of rolling a dice and getting “3”:\n𝑃𝑃 𝑅𝑅𝑅𝑅𝑆𝑆𝑆𝑆 “3” = 𝑃𝑃 𝑦𝑦 = 1\n6\n𝑃𝑃 𝐻𝐻𝑒𝑒𝑆𝑆𝑑𝑑𝐻𝐻 ∗𝑃𝑃 𝑅𝑅𝑅𝑅𝑆𝑆𝑆𝑆 “3” = P 𝑥𝑥, 𝑦𝑦 = 1\n2 ∗\n1\n6 =\n1\n12\n61'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 61, 'page_label': '62'}, page_content='Linear regression finds the straight line, called the least squares \nregression line or LSRL, that best represents observations in a data \nset. Suppose Y is a dependent variable, and X is an independent \nvariable. Then, the equation for the regression line would be: ŷ = \nb0 + b1x\nRegression Review'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 62, 'page_label': '63'}, page_content='63\nGeorge Washington University, Intro to Data Science\nAssumptions\n\uf0d8Linear relationship between dependent and independent - Plot\n\uf0d8Multicollinearity – occurs when independent variables are not \nindependent – checked with VIF \n\uf0d8Auto-correlation – Occurs when residuals are not independent \nfrom each other – stock prices example- Durbin-Watson d tests\n\uf0d8Homoscedasticity – Error term along the regression line are equal \n– Scatter Plot – can convert the dependent variable.'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 63, 'page_label': '64'}, page_content='64\nGeorge Washington University, Intro to Data Science\nRegression\n\uf0d8 Works best with numeric/continuous data to increase the inferential \npower\n\uf0d8 We are trying to model or explain the relationship between a single \nvariable Y (response, output, dependent) and one or more X1….. \n(predictor, input, independent, explanatory, regessors..etc.)\n\uf0d8 Y must be a continuous variable but X categorical, continuous, \n\uf0d8 Centering (scale/Zscores) variables so that the predictors have \nmean 0, is often recommended. The intercept term is then \ninterpreted as the expected value of Yi when the predictor values \nare set to their means. Otherwise, the intercept is interpreted as the \nexpected value of Yi when the predictors are set to 0, which may not \nbe a realistic or interpretable situation (e.g. what if the predictors \nwere height and weight?).'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 64, 'page_label': '65'}, page_content='65\nGeorge Washington University, Intro to Data Science\nWhat Does r2 (Coefficient of Determination) Mean?\nThis statistic quantifies the proportion of the variance of one \nvariable “explained” (in a statistical sense, not a causal sense) by \nthe other.\nAs an example at data set in R (.2697) = 27% of the variability in trunk Height \nis explained by Girth'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 65, 'page_label': '66'}, page_content='66\nGeorge Washington University, Intro to Data Science\nR Regression Output: Coefficients\n\uf0d8 Estimate? Coefficients for the regression equation\n\uf0d8 Standard Error?\nMeasures the average amount that the coefficient estimates vary from the \nactual average value of our response variable, can be used to generate \nconfidence intervals.\n\uf0d8 P value?\nA small p-value indicates that it is unlikely we will observe a relationship \nbetween the predictor (Girth) and response (Height) variables due to chance, a \np-value of .05 or less is considered statistical significant \n\uf0d8 Formula Call? Regression equation'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 66, 'page_label': '67'}, page_content='67\nGeorge Washington University, Intro to Data Science\nR Regression Output\n\uf0d8 Residual Standard Error\nThe average amount that the response will deviate from the true regression line. \nUsed to evaluate our model. \nIn our example we have a residual error of 5.538 in the predication of tree height. \nThe average tree height is 76 meaning we could be off by roughly 7%. \n\uf0d8 Multiple R-squared?\nProvides a measure of how well the model is fitting the actual data, percentage \nof variance explained by the predictors, ours example is 27%'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 67, 'page_label': '68'}, page_content='68\nGeorge Washington University, Intro to Data Science\nVisual'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 68, 'page_label': '69'}, page_content='69\nGeorge Washington University, Intro to Data Science\nBike Share Output'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 69, 'page_label': '70'}, page_content='Another Definition: Functional Approximation\n\uf0d8What is a functional approximation problem?\n\uf076Target variable: Dependent: What we are trying to predict\n\uf076Other Variables: Independent: Using to Predict\n\uf0d8Functional approximation is a approach that uses the other variables \nwe have access to approximate the dependent and does so through \nthe function development\n\uf0d8We will use regression and which assumes that we have a numeric \ntarget variable, for classification it’s often a bi-variate or class level \nvariable \n70'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 70, 'page_label': '71'}, page_content='Assessment Measures \n\uf0d8Assessing Regression Models: MSE, RMSE and MAE\n\uf076MSE – The difference between the predicted values and the actual values \nsquared\n\uf076RSME – Same as above only the square root is taken to put the error back in \nterms of the dependent variable\n\uf0d8 Can also normalize the RSME to the range of the data in order to be able to compare \nRSME outputs that include different data ranges \n\uf076MAE – The same approach only taking the absolute value instead of squaring \n71'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 71, 'page_label': '72'}, page_content='Equations \n72\nn\nXX\nRMSE\nn\ni idelmoiobs∑=\n−\n= 1\n2\n,, )(\nmin,max, obsobs XX\nRMSENRMSE −='),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 72, 'page_label': '73'}, page_content='Linear Regression\n\uf0d8Best used in situations where the data being deploy lacks a high level of \ncomplexity \n\uf0d8Trains very fast but isn’t able to create complex decision boundaries when \ndata is heterogeneous. \n\uf0d8Also as compared to most ML approaches OLS does not have a built in \nfunction that can control for overfitting \n\uf076However not all hope is lost, we can use forward stepwise regression – which we \ndiscussed in Intro to DS or\n\uf076Ridge/Penalized Regression \n73'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 73, 'page_label': '74'}, page_content='Regression \n\uf0d8Said another way basic linear regression has a Prediction Accuracy Problem:\n\uf076Has a low bias (overfitting) but a high variance\n\uf076This can be improved by injecting some level of bias into the equation by reducing the \nimpact of certain coefficients \n\uf076This can improve overall accuracy by reducing variance \n\uf0d8Draw Dart Board –\n\uf0d8Another issue is interpretation – with a large number of predictor variables \nand large data sets it often hard to identify variable importance and explain \nmodel outcomes\n74'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 74, 'page_label': '75'}, page_content='Regression and Sparsity\n\uf0d8Often we have more features than observations in the world of big \ndata\n\uf076What type of problem is this?\n\uf0d8So we strive to have Sparse models\n\uf076What do we mean by Sparse?\n75'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 75, 'page_label': '76'}, page_content='Bias Versus Variance \n76'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 76, 'page_label': '77'}, page_content='Ridge Regression \n\uf0d8Injecting bias can be done through a regulator or utilization of a penalizing \nattribute. two common examples are Ridge and Lasso, let’s start with Ridge\n77\nBasic Regression Equation'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 77, 'page_label': '78'}, page_content='78'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 78, 'page_label': '79'}, page_content='Ridge Penalty \n\uf0d8In this example if 𝛼𝛼is 0 we simply have normal regression equations\n\uf0d8If 𝛼𝛼 is large or ∞ then the 𝛽𝛽 approaches zero and only the constant term is \navailable to predict y\n\uf0d8Essentially provides a weight on the squared residuals during the normal OLS \nprocess \n\uf0d8We want to train the regulator to fall between 0 and 1 using cross-validation \nin such a way that it minimize mean square error\n79\nEssentially the square of the Euclidean norm (magnitude) \nof 𝛽𝛽 which is the vector of coefficientsor\n𝛼𝛼'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 79, 'page_label': '80'}, page_content='Gradient Decent \n\uf0d8Penalized regression methods use a very common algorithm called \ngradient decent\n\uf0d8It is essentially a step function that works to minimize some cost \nfunction through a iterative process\n80'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 80, 'page_label': '81'}, page_content='Gradient Decent \n81'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 81, 'page_label': '82'}, page_content='82'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 82, 'page_label': '83'}, page_content='L2 Norm or Euclidean Norm or Euclidean Length\n\uf0d8Square of all the elements in matrix \n\uf0d8Sum the values together\n\uf0d8Take the square root \n\uf0d8Ridge also squares the final result of this, so we are taking the square \nof the Euclidean norm and multiply this number by the penalty to \nweight the coefficients \n83\nIn words, the L2 normis defined as, 1) square all the elements in the vector together; 2) sum these squared values; and, 3) take the square root of this sum.'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 83, 'page_label': '84'}, page_content='Ridge Visualization\n84'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 84, 'page_label': '85'}, page_content='Measuring the Magnitude of Vectors, L2 and L1\n\uf0d8𝛽𝛽 = 𝛽𝛽0\n𝛽𝛽1\n\uf0d8L2 – Norm : II𝛽𝛽 II2 = 𝛽𝛽0\n2 + 𝛽𝛽1\n2 : What we used for ridge, essentially \ncalculates the magnitude of the coefficient vector of the regression \nequation, gives us a bias minimum \n\uf0d8L1 \n85'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 85, 'page_label': '86'}, page_content='Measuring the Magnitude of Vectors, L2 and L1\n\uf0d8𝛽𝛽 = 𝛽𝛽0\n𝛽𝛽1\n\uf0d8L1 – Norm : II𝛽𝛽 II1 = I𝛽𝛽0I + I𝛽𝛽1I : What we used for ridge, essentially \ncalculates the magnitude of the coefficient vector of the regression \nequation, gives us a bias minimum. Cartesian Distance or Euclidean \nDistance of our vector\n86'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 86, 'page_label': '87'}, page_content='Measuring the Magnitude of Vectors, L2 and L1\n87'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 87, 'page_label': '88'}, page_content='Lasso Equation\n88')]

# %%
spliter = RecursiveCharacterTextSplitter(
    chunk_size=100, # how many small pieces you want the pdf to split into
    chunk_overlap=40)
pages = spliter.split_documents(page)

# %%
pages
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 0, 'page_label': '1'}, page_content='KNN and Probability'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 1, 'page_label': '2'}, page_content='Classification\n\uf0d8Definition\n\uf076Classification can take two distinct meanings in Machine Learning'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 1, 'page_label': '2'}, page_content='\uf0d8Unsupervised Learning \n\uf076We may be given a set of observations with the aim of establishing'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 1, 'page_label': '2'}, page_content='the existence of classes or clusters in the data\n\uf0d8Supervised Learning'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 1, 'page_label': '2'}, page_content='\uf0d8Supervised Learning \n\uf076We may know for certain that there are so many classes, and the aim'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 1, 'page_label': '2'}, page_content='is to establish a rule that we can use to classify a new observation into'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 1, 'page_label': '2'}, page_content='one of the existing classes\n\uf076k-NN is a supervised method for classification \n2'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 2, 'page_label': '3'}, page_content='Classification\n\uf0d8A few classification examples:'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 2, 'page_label': '3'}, page_content='\uf076A Person arrives at the emergency room with a set of symptoms that could'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 2, 'page_label': '3'}, page_content='possibly be attributed to one of three medical conditions. Which of the three'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 2, 'page_label': '3'}, page_content='conditions does the individual have?'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 2, 'page_label': '3'}, page_content='\uf076An online banking service must be able to determine whether or not a'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 2, 'page_label': '3'}, page_content='transaction being performed on the site is fraudulent, on the basis of the'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 2, 'page_label': '3'}, page_content='user’s IP address, past transaction history, and so forth.'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 2, 'page_label': '3'}, page_content='\uf076On the basis of DN sequence data for a number of patients with and without'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 2, 'page_label': '3'}, page_content='a given disease, a biologist would like to figure out which DNA mutations are'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 2, 'page_label': '3'}, page_content='disease-causing and which are not.\n3'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 3, 'page_label': '4'}, page_content='Classification\n\uf0d8There are many possible techniques that a classifier might use to'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 3, 'page_label': '4'}, page_content='predict a qualitative response. Today we will discuss k-NN\n\uf076k-Nearest Neighbors\n\uf076Naïve Bayes'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 3, 'page_label': '4'}, page_content='\uf076k-Nearest Neighbors\n\uf076Naïve Bayes \n\uf076Logistic Regression\n\uf076Tree – based methods\n4'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 4, 'page_label': '5'}, page_content='Classification\nA few issues to keep in mind when building a classifier'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 4, 'page_label': '5'}, page_content='\uf0d8Accuracy. There is the reliability of the rule, usually represented by the'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 4, 'page_label': '5'}, page_content='proportion of correct classifications, although it may be that some errors are'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 4, 'page_label': '5'}, page_content='more serious than others, and it may be important to control the error rate for \nsome key class.'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 4, 'page_label': '5'}, page_content='some key class.\n\uf0d8Speed. In some circumstances, the speed of the classifier is a major issue. A'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 4, 'page_label': '5'}, page_content='classifier that is 85% accurate may be preferred over one that is 95% accurate if it'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 4, 'page_label': '5'}, page_content='is 100 times faster in testing (and such differences in time-scales are not'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 4, 'page_label': '5'}, page_content='uncommon in neural networks for example).'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 4, 'page_label': '5'}, page_content='\uf076Such considerations would be important for the automatic reading of postal'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 4, 'page_label': '5'}, page_content='codes, or automatic fault detection of items on a production line for example.\n5'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 5, 'page_label': '6'}, page_content='Classification\nA few issues to keep in mind when building a classifier'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 5, 'page_label': '6'}, page_content='\uf0d8Comprehensibility. If it is a human operator that must apply the classification'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 5, 'page_label': '6'}, page_content='procedure, the procedure must be easily understood else mistakes will be made'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 5, 'page_label': '6'}, page_content='in applying the rule. It is important also, that human operators believe the \nsystem.'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 5, 'page_label': '6'}, page_content='system. \n\uf0d8Training Time. Especially in a rapidly changing environment, it may be necessary'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 5, 'page_label': '6'}, page_content='to learn a classification rule quickly, or make adjustments to an existing rule in'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 5, 'page_label': '6'}, page_content='real time. “Quickly” might imply also that we need only a small number of'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 5, 'page_label': '6'}, page_content='observations to establish our rule.\n6'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 6, 'page_label': '7'}, page_content='K-Nearest Neighbors\n7'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 7, 'page_label': '8'}, page_content='Simple approach for k-NN\nSimple goal:\n\uf0d8Predict the label of a data point by:'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 7, 'page_label': '8'}, page_content='\uf0d8Predict the label of a data point by:\n\uf076Looking at the ‘k’ closest labeled data points (neighbors)'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 7, 'page_label': '8'}, page_content='\uf076Uses a majority vote'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 7, 'page_label': '8'}, page_content='\uf0d8One of the easiest algorithms to interpret, oftentimes used as a baseline for'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 7, 'page_label': '8'}, page_content='measuring model performance\n\uf0d8Memory-Based Learning'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 7, 'page_label': '8'}, page_content='\uf0d8Memory-Based Learning\n\uf076Also known as “case-based” or “example-based” learning'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 7, 'page_label': '8'}, page_content='\uf0d8Intuition behind memory-based learning\n\uf076Similar inputs map to similar outputs'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 7, 'page_label': '8'}, page_content='\uf076Similar inputs map to similar outputs\n\uf0d8If true, we just have to define “similar”'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 7, 'page_label': '8'}, page_content='\uf0d8 Not all similarities created equal…\n8'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 8, 'page_label': '9'}, page_content='Memory-Based Learning\n\uf0d8How do we determine “similar”?\n\uf0d8For instance, if we wanted to:'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 8, 'page_label': '9'}, page_content='\uf0d8For instance, if we wanted to:\n\uf0d8Predict Brian’s weight\n\uf076Who are the similar people?'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 8, 'page_label': '9'}, page_content='\uf076Who are the similar people?\n\uf076Similar age, diet, height, waistline, activity level …'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 8, 'page_label': '9'}, page_content='\uf0d8Predict Brian’s IQ\n\uf076Similar occupation, writing style, undergraduate degree, SAT \nscore, …'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 8, 'page_label': '9'}, page_content='score, …\n\uf0d8How do we calculate variously ranges in similarity?\n\uf076Need some metric…\n\uf0d8Distance\n9'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 9, 'page_label': '10'}, page_content='k-NN Approach\n\uf0d8Define a distance 𝑑𝑑(𝑥𝑥1, 𝑥𝑥2) between any 2 examples\n\uf076Examples are essentially rows'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 9, 'page_label': '10'}, page_content='\uf076Examples are essentially rows\n\uf076So we could just use Euclidean distance … \n\uf0d8Training'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 9, 'page_label': '10'}, page_content='\uf0d8Training\n\uf076Index the training examples for fast lookup (build a “database”)\n\uf0d8Test'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 9, 'page_label': '10'}, page_content='\uf0d8Test\n\uf076Given a new 𝑥𝑥, find the closest neighbor (k=1) from training index'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 9, 'page_label': '10'}, page_content='\uf076Classify x the same as its closest neighbor\n10'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 10, 'page_label': '11'}, page_content='k-NN Approach\n\uf0d8Euclidean Distance Equation:'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 10, 'page_label': '11'}, page_content='\uf0d8p & z are the current data and q is new, think of p & z as the training and q as the \ntest. \n11'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 10, 'page_label': '11'}, page_content='test. \n11\nx1 x2 x3 x4 x5 x6 x7 x8 Result\nq 3 2 2 5 6 2 1 5\np 4 3 3 6 4 4 5 6'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 10, 'page_label': '11'}, page_content='q 3 2 2 5 6 2 1 5\np 4 3 3 6 4 4 5 6\nEuclidean 1 1 1 1 4 4 16 1 5.39\nz 3 2 2 5 6 2 1 5'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 10, 'page_label': '11'}, page_content='z 3 2 2 5 6 2 1 5\nEuclidean 0 0 0 0 0 0 0 0 0\nSubtracting then \nsquaring row p \nwith q. Then'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 10, 'page_label': '11'}, page_content='squaring row p \nwith q. Then \nsumming and \ntaking the sqrt. \nDo the same with \nz and compare'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 11, 'page_label': '12'}, page_content='kNN Decision Boundaries\n\uf0d8kNN can learn complex decision boundaries\n12'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 12, 'page_label': '13'}, page_content='\uf0d8Instead of picking the (1) nearest neighbor, what if we picked the'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 12, 'page_label': '13'}, page_content='k-Nearest Neighbors and have them vote?\n\uf0d8Choosing k points is more reliable in the following cases:'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 12, 'page_label': '13'}, page_content='\uf076Noise in training vectors x\n\uf076Noise in training labels y\n\uf076Overlapping classes\nkNN\n13\nx_1\nx_2\n++\n+\n+'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 12, 'page_label': '13'}, page_content='kNN\n13\nx_1\nx_2\n++\n+\n+\n+\n++++\no\no\no\no\no\nooo oo\no\n+\n+\n+o\no o\nk=1'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 13, 'page_label': '14'}, page_content='kNN\n\uf0d8Instead of picking the (1) nearest neighbor, what if we picked the'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 13, 'page_label': '14'}, page_content='k-Nearest Neighbors and have them vote?\n\uf0d8Choosing k points is more reliable in the following cases:'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 13, 'page_label': '14'}, page_content='\uf076Noise in training vectors x\n\uf076Noise in training labels y\n\uf076Overlapping classes\n\uf0d8Why?\n14\nx_1\nx_2 ++\n+'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 13, 'page_label': '14'}, page_content='\uf0d8Why?\n14\nx_1\nx_2 ++\n+\n+\n+\n++++\no\no\no\no\no\nooo oo\no\n+\n+\n+o\no o\nk=1X'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 14, 'page_label': '15'}, page_content='kNN Decision Boundaries\n\uf0d8Consider this example with R,G,B classes \nwith significant overlap\n15'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 15, 'page_label': '16'}, page_content='kNN Decision Boundaries\n\uf0d8Consider this example with R,G,B classes \nwith significant overlap'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 15, 'page_label': '16'}, page_content='with significant overlap\n\uf0d8k=1 Decision Boundary\n\uf076Looks complex\n\uf076Overfitting?\n16'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 16, 'page_label': '17'}, page_content='kNN Decision Boundaries\n\uf0d8k=1 Decision Boundary\n\uf076Looks complex\n\uf076Overfitting?'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 16, 'page_label': '17'}, page_content='\uf076Looks complex\n\uf076Overfitting?\n\uf0d8What if we were to increase k?\n17'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 17, 'page_label': '18'}, page_content='kNN Decision Boundaries\n\uf0d8k=1 Decision Boundary\n\uf076Looks complex\n\uf076Overfitting?'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 17, 'page_label': '18'}, page_content='\uf076Looks complex\n\uf076Overfitting?\n\uf0d8What if we were to increase k?\n\uf076K=15 Decision boundary\n18'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 18, 'page_label': '19'}, page_content='kNN Decision Boundaries\n\uf0d8k=1 Decision Boundary\n\uf076Looks complex\n\uf076Overfitting?'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 18, 'page_label': '19'}, page_content='\uf076Looks complex\n\uf076Overfitting?\n\uf0d8What if we were to increase k?\n\uf076K=15 Decision boundary'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 18, 'page_label': '19'}, page_content='\uf076K=15 Decision boundary\n\uf076Smoother boundaries\n19'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 19, 'page_label': '20'}, page_content='kNN Decision Boundaries\n\uf0d8k=1 Decision Boundary\n\uf076Looks complex\n\uf076Overfitting?'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 19, 'page_label': '20'}, page_content='\uf076Looks complex\n\uf076Overfitting?\n\uf0d8What if we were to increase k?\n\uf076K=15 Decision boundary'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 19, 'page_label': '20'}, page_content='\uf076K=15 Decision boundary\n\uf076Smoother boundaries\n\uf076Generalizes better on unseen data\n20'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 20, 'page_label': '21'}, page_content='kNN Decision Boundaries\n\uf0d8k=1 Decision Boundary\n\uf076Looks complex\n\uf076Overfitting?'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 20, 'page_label': '21'}, page_content='\uf076Looks complex\n\uf076Overfitting?\n\uf0d8What if we were to increase k?\n\uf076K=15 Decision boundary'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 20, 'page_label': '21'}, page_content='\uf076K=15 Decision boundary\n\uf076Smoother boundaries\n\uf076Generalizes better on unseen data'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 20, 'page_label': '21'}, page_content='\uf076Generalizes better on unseen data\n\uf0d8What makes the boundaries smoother?\n21'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 21, 'page_label': '22'}, page_content='kNN Decision Boundaries\n\uf0d8k=1 Decision Boundary\n\uf076Looks complex\n\uf076Overfitting?'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 21, 'page_label': '22'}, page_content='\uf076Looks complex\n\uf076Overfitting?\n\uf0d8What if we were to increase k?\n\uf076K=15 Decision boundary'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 21, 'page_label': '22'}, page_content='\uf076K=15 Decision boundary\n\uf076Smoother boundaries\n\uf076Generalizes better on unseen data'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 21, 'page_label': '22'}, page_content='\uf076Generalizes better on unseen data\n\uf0d8What makes the boundaries smoother?'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 21, 'page_label': '22'}, page_content='\uf0d8What makes the boundaries smoother?\n\uf0d8Let’s look at a two-class (binary) example\n22'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 22, 'page_label': '23'}, page_content='k-NN Graphical Example\n23\n\uf0d8Consider this two-dimensional dataset with'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 22, 'page_label': '23'}, page_content='points classified as Red or Green'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 23, 'page_label': '24'}, page_content='k-NN Graphical Example\n24\n\uf0d8Consider this two-dimensional dataset with'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 23, 'page_label': '24'}, page_content='points classified as Red or Green \n\uf0d8We want to Classify this point'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 24, 'page_label': '25'}, page_content='k-NN Graphical Example\n25\n\uf0d8Consider this two-dimensional dataset with'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 24, 'page_label': '25'}, page_content='points classified as Red or Green \n\uf0d8We want to Classify this point\n\uf0d8If we consider k=3 neighbors'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 25, 'page_label': '26'}, page_content='k-NN Graphical Example\n26\n\uf0d8Consider this two-dimensional dataset with'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 25, 'page_label': '26'}, page_content='points classified as Red or Green \n\uf0d8We want to Classify this point\n\uf0d8If we consider k=3 neighbors'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 25, 'page_label': '26'}, page_content='\uf0d8If we consider k=3 neighbors \n\uf076Measured by some distance\nd'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 26, 'page_label': '27'}, page_content='k-NN Graphical Example\n27\n\uf0d8Consider this two-dimensional dataset with'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 26, 'page_label': '27'}, page_content='points classified as Red or Green \n\uf0d8We want to Classify this point\n\uf0d8If we consider k=3 neighbors'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 26, 'page_label': '27'}, page_content='\uf0d8If we consider k=3 neighbors \n\uf076Measured by some distance\n\uf076The point is classified as Red'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 27, 'page_label': '28'}, page_content='k-NN Graphical Example\n28\n\uf0d8Consider this two-dimensional dataset with'),
# ...
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 74, 'page_label': '75'}, page_content='data\n\uf076What type of problem is this?\n\uf0d8So we strive to have Sparse models\n\uf076What do we mean by Sparse?'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 74, 'page_label': '75'}, page_content='\uf076What do we mean by Sparse?\n75'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 75, 'page_label': '76'}, page_content='Bias Versus Variance \n76'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 76, 'page_label': '77'}, page_content='Ridge Regression \n\uf0d8Injecting bias can be done through a regulator or utilization of a penalizing'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 76, 'page_label': '77'}, page_content='attribute. two common examples are Ridge and Lasso, let’s start with Ridge\n77'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 76, 'page_label': '77'}, page_content='77\nBasic Regression Equation'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 77, 'page_label': '78'}, page_content='78'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 78, 'page_label': '79'}, page_content='Ridge Penalty \n\uf0d8In this example if 𝛼𝛼is 0 we simply have normal regression equations'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 78, 'page_label': '79'}, page_content='\uf0d8If 𝛼𝛼 is large or ∞ then the 𝛽𝛽 approaches zero and only the constant term is'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 78, 'page_label': '79'}, page_content='available to predict y'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 78, 'page_label': '79'}, page_content='\uf0d8Essentially provides a weight on the squared residuals during the normal OLS \nprocess'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 78, 'page_label': '79'}, page_content='process \n\uf0d8We want to train the regulator to fall between 0 and 1 using cross-validation'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 78, 'page_label': '79'}, page_content='in such a way that it minimize mean square error\n79'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 78, 'page_label': '79'}, page_content='79\nEssentially the square of the Euclidean norm (magnitude)'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 78, 'page_label': '79'}, page_content='of 𝛽𝛽 which is the vector of coefficientsor\n𝛼𝛼'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 79, 'page_label': '80'}, page_content='Gradient Decent \n\uf0d8Penalized regression methods use a very common algorithm called \ngradient decent'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 79, 'page_label': '80'}, page_content='gradient decent\n\uf0d8It is essentially a step function that works to minimize some cost'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 79, 'page_label': '80'}, page_content='function through a iterative process\n80'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 80, 'page_label': '81'}, page_content='Gradient Decent \n81'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 81, 'page_label': '82'}, page_content='82'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 82, 'page_label': '83'}, page_content='L2 Norm or Euclidean Norm or Euclidean Length\n\uf0d8Square of all the elements in matrix'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 82, 'page_label': '83'}, page_content='\uf0d8Square of all the elements in matrix \n\uf0d8Sum the values together\n\uf0d8Take the square root'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 82, 'page_label': '83'}, page_content='\uf0d8Take the square root \n\uf0d8Ridge also squares the final result of this, so we are taking the square'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 82, 'page_label': '83'}, page_content='of the Euclidean norm and multiply this number by the penalty to \nweight the coefficients \n83'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 82, 'page_label': '83'}, page_content='In words, the L2 normis defined as, 1) square all the elements in the vector together; 2) sum these'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 82, 'page_label': '83'}, page_content='in the vector together; 2) sum these squared values; and, 3) take the square root of this sum.'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 83, 'page_label': '84'}, page_content='Ridge Visualization\n84'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 84, 'page_label': '85'}, page_content='Measuring the Magnitude of Vectors, L2 and L1\n\uf0d8𝛽𝛽 = 𝛽𝛽0\n𝛽𝛽1\n\uf0d8L2 – Norm : II𝛽𝛽 II2 = 𝛽𝛽0\n2 + 𝛽𝛽1'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 84, 'page_label': '85'}, page_content='𝛽𝛽1\n\uf0d8L2 – Norm : II𝛽𝛽 II2 = 𝛽𝛽0\n2 + 𝛽𝛽1\n2 : What we used for ridge, essentially'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 84, 'page_label': '85'}, page_content='calculates the magnitude of the coefficient vector of the regression'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 84, 'page_label': '85'}, page_content='equation, gives us a bias minimum \n\uf0d8L1 \n85'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 85, 'page_label': '86'}, page_content='Measuring the Magnitude of Vectors, L2 and L1\n\uf0d8𝛽𝛽 = 𝛽𝛽0\n𝛽𝛽1'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 85, 'page_label': '86'}, page_content='\uf0d8𝛽𝛽 = 𝛽𝛽0\n𝛽𝛽1\n\uf0d8L1 – Norm : II𝛽𝛽 II1 = I𝛽𝛽0I + I𝛽𝛽1I : What we used for ridge, essentially'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 85, 'page_label': '86'}, page_content='calculates the magnitude of the coefficient vector of the regression'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 85, 'page_label': '86'}, page_content='equation, gives us a bias minimum. Cartesian Distance or Euclidean \nDistance of our vector\n86'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 86, 'page_label': '87'}, page_content='Measuring the Magnitude of Vectors, L2 and L1\n87'),
#  Document(metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 87, 'page_label': '88'}, page_content='Lasso Equation\n88')]

# %%
vector_storage = FAISS.from_documents(
    pages,
    OpenAIEmbeddings(),
)
retriever = vector_storage.as_retriever()

# %%
question_retriever = """
You are a helpful assistant. You will be given a question and a context.
Your task is to answer the question based on the context provided.
If the context does not contain enough information to answer the question, say "I don't know".

context: {context}
question: {question}

"""

# %%
prompt = PromptTemplate.from_template(template=question_retriever)
print(prompt.format(context = 'Here is the context',
              question = 'Answer the question based on the context'
              ))
# Out:
# You are a helpful assistant. You will be given a question and a context.
# Your task is to answer the question based on the context provided.
# If the context does not contain enough information to answer the question, say "I don't know".
#
# context: Here is the context
# question: Answer the question based on the context

# %%
results = RunnableParallel(context = retriever, question = RunnablePassthrough())

# %%
chain = results | prompt | llm | parser

# %%
chain.invoke('what is coding?')
# Out:
# "I don't know."

# %%
chain.invoke('what is knn?')
# Out:
# 'KNN, or K-Nearest Neighbors, is a supervised method for classification.'

# %%
retriever.invoke('what is knn?')
# Out:
# [Document(id='77fadf2c-902c-4aa7-8a4b-821d4cae1fcd', metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 0, 'page_label': '1'}, page_content='KNN and Probability'),
#  Document(id='9d77f66d-63b2-460e-956c-e37431526b08', metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 1, 'page_label': '2'}, page_content='one of the existing classes\n\uf076k-NN is a supervised method for classification \n2'),
#  Document(id='09f06267-067a-4758-b636-79b10dbd4c21', metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 12, 'page_label': '13'}, page_content='kNN\n13\nx_1\nx_2\n++\n+\n+\n+\n++++\no\no\no\no\no\nooo oo\no\n+\n+\n+o\no o\nk=1'),
#  Document(id='9ad75ef8-93db-4cbc-8322-f5f7b44465b9', metadata={'producer': 'Adobe PDF Library 20.4.68', 'creator': 'Acrobat PDFMaker 20 for PowerPoint', 'creationdate': '2022-02-21T16:21:50-05:00', 'author': 'Larry Medsker', 'moddate': '2022-02-21T16:22:38-05:00', 'title': 'PowerPoint Presentation', 'source': 'Knn and Prob-1.pdf', 'total_pages': 88, 'page': 6, 'page_label': '7'}, page_content='K-Nearest Neighbors\n7')]
